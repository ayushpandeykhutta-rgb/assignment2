# %% [markdown]
# 1. Write a user-defined function that takes a number as input and returns:
# • "Positive Even"
# • "Positive Odd"
# • "Negative"
# • "Zero"
# Use proper conditional statements and explain your logic.

# %%
def check_number(num):
    if num == 0:
        return "Zero"
    elif num < 0:
        return "Negative"
    elif num % 2 == 0:
        return "Positive Even"
    else:
        return "Positive Odd"

# %% [markdown]
# 2. Write a function that accepts three numbers and returns the largest number without using built-in
# functions like max().
# Explain how your conditional structure ensures correctness.

# %%
def find_largest(a, b, c):
    # Check if 'a' is greater than or equal to both 'b' and 'c'
    if a >= b and a >= c:
        largest = a
    
    # Check if 'b' is greater than or equal to both 'a' and 'c'
    elif b >= a and b >= c:
        largest = b
    
    # If neither 'a' nor 'b' is the largest, then 'c' must be largest
    else:
        largest = c
    
    return largest

# %% [markdown]
# 3. Write a function that accepts a student’s marks and returns the grade based on the following logic:
# • 90+ → A
# • 75–89 → B
# • 50–74 → C
# • Below 50 → Fail
# Use nested conditional statements and justify your approach.

# %%
def calculate_grade(marks):
    if marks >= 50:
        if marks >= 90:
            return "A"
        elif marks >= 75:
            return "B"
        else:
            return "C"
    else:
        return "Fail"


# Example
print(calculate_grade(92))   # A
print(calculate_grade(80))   # B
print(calculate_grade(60))   # C
print(calculate_grade(40))   # Fail

# %% [markdown]
# 4. Write a function that takes age as input.
# • If age is negative, raise an error.
# • If age is below 18, return "Minor", otherwise return "Adult".
# Explain how conditional statements help in input validation.

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative")
    elif age < 18:
        return "Minor"
    else:
        return "Adult"


# Example
print(check_age(15))   # Minor
print(check_age(25))   # Adult
print(check_age(-5))   # Error

# %% [markdown]
# 5. Write a function that accepts a list of integers and:
# • Counts even numbers
# • Ignores negative numbers
# • Stops processing if zero appears
# Use both loops and conditional statements inside the function.

# %%
def count_even_numbers(numbers):
    count = 0
    
    for num in numbers:
        
        # Stop processing if zero appears
        if num == 0:
            break
        
        # Ignore negative numbers
        if num < 0:
            continue
        
        # Count even numbers
        if num % 2 == 0:
            count += 1
    
    return count


# Example usage
num_list = [4, -2, 7, 8, 0, 10, 12]
result = count_even_numbers(num_list)

print("Count of even numbers:", result)
